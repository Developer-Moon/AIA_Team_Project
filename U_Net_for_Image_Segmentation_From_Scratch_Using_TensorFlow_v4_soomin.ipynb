# %% [markdown]
# <a href="https://colab.research.google.com/github/VidushiBhatia/U-Net-Implementation/blob/main/U_Net_for_Image_Segmentation_From_Scratch_Using_TensorFlow_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Segmentation with U-Net
#
# This notebook consists of an implementation of U-Net using the following resources:
# * **Algorithm**: Ronneberger et al., [U-Net](https://arxiv.org/abs/1505.04597) Convolutional Networks for Biomedical Image Segmentation
# * **Dataset**: [oxford iiit pet dataset](https://www.kaggle.com/tanlikesmath/the-oxfordiiit-pet-dataset) (published by Kaggle)
# * **Packages Used**: TensorFlow, NumPy, scikit-learn, python-Pillow, imageio, matplotlib

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Code Breakdown
#
# - [1 - Packages](#1)
# - [2 - Helper Functions for Data Processing](#2)
#     - [2.1 - Load Data](#2.1)
#     - [2.2 - Pre-Process Data](#2.2)
# - [3 - Helper Functions for U-Net Architecture](#3)
#     - [3.1 - U-Net Encoder Block](#3.1)
#     - [3.2 - U-Net Decoder Block](#3.2)
#     - [3.3 - Compile U-Net Blocks](#3.3)
# - [4 - Executing above Functions to Train the Model](#4)
#     - [4.1 - Load and View Data](#4.1)
#     - [4.2 - Process Data](#4.2)
#     - [4.3 - Split Train and Test](#4.3)
#     - [4.4 - Build U-Net Architecture](#4.4)
#     - [4.5 - Compile and Run Model](#4.5)
# - [5 - Evaluate Results](#5)
#     - [5.1 - Bias-Variance Check](#5.1)
#     - [5.2 - View Predicted Segmentations](#5.2)

# %% [markdown]
# <a name='1'></a>
# # 1 - Packages

# %%
# for data load
import os

# for reading and processing images
import imageio
from PIL import Image

# for visualizations
import matplotlib.pyplot as plt

import numpy as np # for using np arrays

# for bulding and running deep learning model
import tensorflow as tf
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout 
from keras.layers import BatchNormalization
from keras.layers import Conv2DTranspose
from keras.layers import concatenate
from keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split

# %% [markdown]
# <a name='2'></a>
# # 2 - Helper Functions for Data Processing

# %% [markdown]
# <a name='2.1'></a>
# ## 2.1 - Load Data
# * the masked images are stored as png, unmasked (original) as jpg
# * the names of these 2 are same so for getting the right sample we can just sort the 2 lists

# %%
def LoadData (path1, path2):
    """
    Looks for relevant filenames in the shared path
    Returns 2 lists for original and masked files respectively
    
    """
    # Read the images folder like a list
    image_dataset = os.listdir(path1)
    mask_dataset = os.listdir(path2)

    # Make a list for images and masks filenames
    orig_img = []
    mask_img = []
    for file in image_dataset:
        orig_img.append(file)
    for file in mask_dataset:
        mask_img.append(file)

    # Sort the lists to get both of them in same order (the dataset has exactly the same name for images and corresponding masks)
    orig_img.sort()
    mask_img.sort()
    
    return orig_img, mask_img

# %% [markdown]
# <a name='2.2'></a>
# ## 2.2 - Pre-Process Data

# %%
def PreprocessData(img, mask, target_shape_img, target_shape_mask, path1, path2):
    """
    Processes the images and mask present in the shared list and path
    Returns a NumPy dataset with images as 3-D arrays of desired size
    Please note the masks in this dataset have only one channel
    """
    # Pull the relevant dimensions for image and mask
    m = len(img)                     # number of images
    i_h,i_w,i_c = target_shape_img   # pull height, width, and channels of image
    m_h,m_w,m_c = target_shape_mask  # pull height, width, and channels of mask
    
    # Define X and Y as number of images along with shape of one image
    X = np.zeros((m,i_h,i_w,i_c), dtype=np.float32)
    y = np.zeros((m,m_h,m_w,m_c), dtype=np.int32)
    
    # Resize images and masks
    for file in img:
        # convert image into an array of desired shape (3 channels)
        index = img.index(file)
        path = os.path.join(path1, file)
        single_img = Image.open(path).convert('RGB')
        single_img = single_img.resize((i_h,i_w))
        single_img = np.reshape(single_img,(i_h,i_w,i_c)) 
        single_img = single_img/256.
        X[index] = single_img
        
        # convert mask into an array of desired shape (1 channel)
        single_mask_ind = mask[index]
        path = os.path.join(path2, single_mask_ind)
        single_mask = Image.open(path)
        single_mask = single_mask.resize((m_h, m_w))
        single_mask = np.reshape(single_mask,(m_h,m_w,m_c)) 
        single_mask = single_mask - 1 # to ensure classes #s start from 0
        y[index] = single_mask
    return X, y

# %% [markdown]
# <a name='3'></a>
# #3 - Constructing the U-Net Architecture

# %% [markdown]
# <a name='3.1'></a>
# ## 3.1 - U-Net Encoder Block

# %%
def EncoderMiniBlock(inputs, n_filters=32, dropout_prob=0.3, max_pooling=True):
    """
    This block uses multiple convolution layers, max pool, relu activation to create an architecture for learning. 
    Dropout can be added for regularization to prevent overfitting. 
    The block returns the activation values for next layer along with a skip connection which will be used in the decoder
    """
    # Add 2 Conv Layers with relu activation and HeNormal initialization using TensorFlow 
    # Proper initialization prevents from the problem of exploding and vanishing gradients 
    # 'Same' padding will pad the input to conv layer such that the output has the same height and width (hence, is not reduced in size) 
    conv = Conv2D(n_filters, 
                  3,   # Kernel size   
                  activation='relu',
                  padding='same',
                  kernel_initializer='HeNormal')(inputs)
    conv = Conv2D(n_filters, 
                  3,   # Kernel size
                  activation='relu',
                  padding='same',
                  kernel_initializer='HeNormal')(conv)
    
    # Batch Normalization will normalize the output of the last layer based on the batch's mean and standard deviation
    conv = BatchNormalization()(conv, training=False)

    # In case of overfitting, dropout will regularize the loss and gradient computation to shrink the influence of weights on output
    if dropout_prob > 0:     
        conv = tf.keras.layers.Dropout(dropout_prob)(conv)

    # Pooling reduces the size of the image while keeping the number of channels same
    # Pooling has been kept as optional as the last encoder layer does not use pooling (hence, makes the encoder block flexible to use)
    # Below, Max pooling considers the maximum of the input slice for output computation and uses stride of 2 to traverse across input image
    if max_pooling:
        next_layer = tf.keras.layers.MaxPooling2D(pool_size = (2,2))(conv)    
    else:
        next_layer = conv

    # skip connection (without max pooling) will be input to the decoder layer to prevent information loss during transpose convolutions      
    skip_connection = conv
    
    return next_layer, skip_connection

# %% [markdown]
# <a name='3.2'></a>
# ## 3.2 - U-Net Decoder Block

# %%
def DecoderMiniBlock(prev_layer_input, skip_layer_input, n_filters=32):
    """
    Decoder Block first uses transpose convolution to upscale the image to a bigger size and then,
    merges the result with skip layer results from encoder block
    Adding 2 convolutions with 'same' padding helps further increase the depth of the network for better predictions
    The function returns the decoded layer output
    """
    # Start with a transpose convolution layer to first increase the size of the image
    up = Conv2DTranspose(
                 n_filters,
                 (3,3),    # Kernel size
                 strides=(2,2),
                 padding='same')(prev_layer_input)

    # Merge the skip connection from previous block to prevent information loss
    merge = concatenate([up, skip_layer_input], axis=3)
    
    # Add 2 Conv Layers with relu activation and HeNormal initialization for further processing
    # The parameters for the function are similar to encoder
    conv = Conv2D(n_filters, 
                 3,     # Kernel size
                 activation='relu',
                 padding='same',
                 kernel_initializer='HeNormal')(merge)
    conv = Conv2D(n_filters,
                 3,   # Kernel size
                 activation='relu',
                 padding='same',
                 kernel_initializer='HeNormal')(conv)
    return conv

# %% [markdown]
# <a name='3.3'></a>
# ## 3.3 - Compile U-Net Blocks

# %%
def UNetCompiled(input_size=(128, 128, 3), n_filters=32, n_classes=3):
   """
   Combine both encoder and decoder blocks according to the U-Net research paper
   Return the model as output 
"""
   # Input size represent the size of 1 image (the size used for pre-processing) 
   inputs = Input(input_size)
   
   # Encoder includes multiple convolutional mini blocks with different maxpooling, dropout and filter parameters
   # Observe that the filters are increasing as we go deeper into the network which will increasse the # channels of the image 
   cblock1 = EncoderMiniBlock(inputs, n_filters,dropout_prob=0, max_pooling=True)
   cblock2 = EncoderMiniBlock(cblock1[0],n_filters*2,dropout_prob=0, max_pooling=True)
   cblock3 = EncoderMiniBlock(cblock2[0], n_filters*4,dropout_prob=0, max_pooling=True)
   cblock4 = EncoderMiniBlock(cblock3[0], n_filters*8,dropout_prob=0.3, max_pooling=True)
   cblock5 = EncoderMiniBlock(cblock4[0], n_filters*16, dropout_prob=0.3, max_pooling=False) 
   
   # Decoder includes multiple mini blocks with decreasing number of filters
   # Observe the skip connections from the encoder are given as input to the decoder
   # Recall the 2nd output of encoder block was skip connection, hence cblockn[1] is used
   ublock6 = DecoderMiniBlock(cblock5[0], cblock4[1],  n_filters * 8)
   ublock7 = DecoderMiniBlock(ublock6, cblock3[1],  n_filters * 4)
   ublock8 = DecoderMiniBlock(ublock7, cblock2[1],  n_filters * 2)
   ublock9 = DecoderMiniBlock(ublock8, cblock1[1],  n_filters)

   # Complete the model with 1 3x3 convolution layer (Same as the prev Conv Layers)
   # Followed by a 1x1 Conv layer to get the image to the desired size. 
   # Observe the number of channels will be equal to number of output classes
   conv9 = Conv2D(n_filters,
               3,
               activation='relu',
               padding='same',
               kernel_initializer='he_normal')(ublock9)

   conv10 = Conv2D(n_classes, 1, padding='same')(conv9)
   
   # Define the model
   model = tf.keras.Model(inputs=inputs, outputs=conv10)

   return model

# %% [markdown]
# <a name='4'></a>
# # 4 - Executing above Functions to Train the Model

# %% [markdown]
# <a name='4.1'></a>
# ## 4.1 - Load and View Data

# %%
""" Load Train Set and view some examples """
# Call the apt function
path1 = 'C:/Users/aia200/OneDrive_KNOU/data/oxford pets/images/images/'
path2 = 'C:/Users/aia200/OneDrive_KNOU/data/oxford pets/annotations/annotations/trimaps/'
img, mask = LoadData (path1, path2)

# View an example of image and corresponding mask 
show_images = 1
for i in range(show_images):
    img_view  = imageio.imread(path1 + img[i])
    mask_view = imageio.imread(path2 + mask[i])
    print(img_view.shape)
    print(mask_view.shape)
    fig, arr = plt.subplots(1, 2, figsize=(15, 15))
    arr[0].imshow(img_view)
    arr[0].set_title('Image '+ str(i))
    arr[1].imshow(mask_view)
    arr[1].set_title('Masked Image '+ str(i))
# Out:
# (400, 600, 3)
# (400, 600)

# %% [markdown]
# <a name='4.2'></a>
# ## 4.2 - Process Data

# %%
# Define the desired shape
target_shape_img = [128, 128, 3]
target_shape_mask = [128, 128, 1]

# Process data using apt helper function
X, y = PreprocessData(img, mask, target_shape_img, target_shape_mask, path1, path2)

# QC the shape of output and classes in output dataset 
print("X Shape:", X.shape)
print("Y shape:", y.shape)
# There are 3 classes : background, pet, outline
print(np.unique(y))

# Visualize the output
image_index = 0
fig, arr = plt.subplots(1, 2, figsize=(15, 15))
arr[0].imshow(X[image_index])
arr[0].set_title('Processed Image')
arr[1].imshow(y[image_index,:,:,0])
arr[1].set_title('Processed Masked Image ')
# Out:
# X Shape: (7390, 128, 128, 3)
# Y shape: (7390, 128, 128, 1)
# [0 1 2]
# Text(0.5, 1.0, 'Processed Masked Image ')

# %% [markdown]
# ## 4.3 - Split Train and Test Set

# %%
# Use scikit-learn's function to split the dataset
# Here, I have used 20% data as test/valid set
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=123)

# %% [markdown]
# <a name='4.4'></a>
# ## 4.4 - Build U-Net Architecture

# %%
# Call the helper function for defining the layers for the model, given the input image size
unet = UNetCompiled(input_size=(128,128,3), n_filters=32, n_classes=3)

# %%
# Check the summary to better interpret how the output dimensions change in each layer
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d_1[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['batch_normalization_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 16, 16, 256)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 512)    1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 512)    2359808     ['conv2d_8[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 512)   2048        ['conv2d_9[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 8, 8, 512)    0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 256)  1179904    ['dropout_1[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'dropout[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  73792       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 32  18464      ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'batch_normalization[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 32  9248        ['conv2d_17[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 3)  99          ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 8,643,779
# Trainable params: 8,641,795
# Non-trainable params: 1,984
# __________________________________________________________________________________________________

# %% [markdown]
# <a name='4.5'></a>
# ## 4.5 - Compile and Run Model

# %%
# There are multiple optimizers, loss functions and metrics that can be used to compile multi-class segmentation models
# Ideally, try different options to get the best accuracy
unet.compile(optimizer=tf.keras.optimizers.Adam(), 
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Run the model in a mini-batch fashion and compute the progress for each epoch
results = unet.fit(X_train, y_train, batch_size=32, epochs=4000, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/4000
# 185/185 [==============================] - 32s 106ms/step - loss: 0.7884 - accuracy: 0.6634 - val_loss: 0.6205 - val_accuracy: 0.7481
# Epoch 2/4000
# 185/185 [==============================] - 18s 95ms/step - loss: 0.5997 - accuracy: 0.7600 - val_loss: 0.5497 - val_accuracy: 0.7863
# Epoch 3/4000
# 185/185 [==============================] - 18s 96ms/step - loss: 0.4960 - accuracy: 0.8057 - val_loss: 0.4534 - val_accuracy: 0.8245
# Epoch 4/4000
# 185/185 [==============================] - 18s 96ms/step - loss: 0.4276 - accuracy: 0.8352 - val_loss: 0.4268 - val_accuracy: 0.8362
# Epoch 5/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.4014 - accuracy: 0.8461 - val_loss: 0.3872 - val_accuracy: 0.8519
# Epoch 6/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.3741 - accuracy: 0.8572 - val_loss: 0.4071 - val_accuracy: 0.8422
# Epoch 7/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.3520 - accuracy: 0.8661 - val_loss: 0.3582 - val_accuracy: 0.8640
# Epoch 8/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.3344 - accuracy: 0.8730 - val_loss: 0.3597 - val_accuracy: 0.8639
# Epoch 9/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.3152 - accuracy: 0.8811 - val_loss: 0.3678 - val_accuracy: 0.8613
# Epoch 10/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.3105 - accuracy: 0.8822 - val_loss: 0.3369 - val_accuracy: 0.8716
# Epoch 11/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.2888 - accuracy: 0.8909 - val_loss: 0.3315 - val_accuracy: 0.8741
# Epoch 12/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.2828 - accuracy: 0.8932 - val_loss: 0.3304 - val_accuracy: 0.8767
# Epoch 13/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.2696 - accuracy: 0.8981 - val_loss: 0.3401 - val_accuracy: 0.8774
# Epoch 14/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.2593 - accuracy: 0.9018 - val_loss: 0.3418 - val_accuracy: 0.8790
# Epoch 15/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.2603 - accuracy: 0.9014 - val_loss: 0.3203 - val_accuracy: 0.8795
# Epoch 16/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0
4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0610 - accuracy: 0.9747 - val_loss: 0.6345 - val_accuracy: 0.8887
# Epoch 257/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0583 - accuracy: 0.9757 - val_loss: 0.6434 - val_accuracy: 0.8886
# Epoch 258/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0564 - accuracy: 0.9765 - val_loss: 0.6602 - val_accuracy: 0.8879
# Epoch 259/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0554 - accuracy: 0.9769 - val_loss: 0.6787 - val_accuracy: 0.8883
# Epoch 260/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0544 - accuracy: 0.9773 - val_loss: 0.6991 - val_accuracy: 0.8880
# Epoch 261/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0543 - accuracy: 0.9773 - val_loss: 0.6971 - val_accuracy: 0.8876
# Epoch 262/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0547 - accuracy: 0.9772 - val_loss: 0.7168 - val_accuracy: 0.8883
# Epoch 263/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0541 - accuracy: 0.9774 - val_loss: 0.7205 - val_accuracy: 0.8878
# Epoch 264/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0533 - accuracy: 0.9777 - val_loss: 0.7195 - val_accuracy: 0.8877
# Epoch 265/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0537 - accuracy: 0.9776 - val_loss: 0.6396 - val_accuracy: 0.8846
# Epoch 266/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0567 - accuracy: 0.9764 - val_loss: 0.7096 - val_accuracy: 0.8881
# Epoch 267/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0543 - accuracy: 0.9773 - val_loss: 0.6798 - val_accuracy: 0.8883
# Epoch 268/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0541 - accuracy: 0.9774 - val_loss: 0.6924 - val_accuracy: 0.8869
# Epoch 269/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0535 - accuracy: 0.9776 - val_loss: 0.7199 - val_accuracy: 0.8877
# Epoch 270/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0536 - accuracy: 0.9776 - val_loss: 0.7208 - val_accuracy: 0.8876
# Epoch 271/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0543 - accuracy: 0.9774 - val_loss: 0.7252 - val_accuracy: 0.8881
# Epoch 272/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0541 - accuracy: 0.9774 - val_loss: 0.6817 - val_accuracy: 0.8866
# Epoch 273/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0542 - accuracy: 0.9774 - val_loss: 0.7394 - val_accuracy: 0.8865
# Epoch 274/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0534 - accuracy: 0.9777 - val_loss: 0.7127 - val_accuracy: 0.8869
# Epoch 275/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0537 - accuracy: 0.9776 - val_loss: 0.7196 - val_accuracy: 0.8871
# Epoch 276/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0535 - accuracy: 0.9777 - val_loss: 0.7610 - val_accuracy: 0.8870
# Epoch 277/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0537 - accuracy: 0.9776 - val_loss: 0.7344 - val_accuracy: 0.8875
# Epoch 278/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0537 - accuracy: 0.9776 - val_loss: 0.7413 - val_accuracy: 0.8859
# Epoch 279/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0537 - accuracy: 0.9776 - val_loss: 0.7259 - val_accuracy: 0.8868
# Epoch 280/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0593 - accuracy: 0.9755 - val_loss: 0.7037 - val_accuracy: 0.8883
# Epoch 281/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0554 - accuracy: 0.9769 - val_loss: 0.7196 - val_accuracy: 0.8862
# Epoch 282/4000
# 185/185 [==============================] - 18s 97ms/step - loss: 0.0540 - accuracy: 0.9774 - val_loss: 0.7443 - val_accuracy: 0.8872
# Epoch 283/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0527 - accuracy: 0.9780 - val_loss: 0.7773 - val_accuracy: 0.8864
# Epoch 284/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0566 - accuracy: 0.9765 - val_loss: 0.6934 - val_accuracy: 0.8867
# Epoch 285/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0537 - accuracy: 0.9776 - val_loss: 0.7645 - val_accuracy: 0.8869
# Epoch 286/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.
4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0479 - accuracy: 0.9798 - val_loss: 0.7509 - val_accuracy: 0.8869
# Epoch 316/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0482 - accuracy: 0.9797 - val_loss: 0.7373 - val_accuracy: 0.8869
# Epoch 317/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0485 - accuracy: 0.9796 - val_loss: 0.7667 - val_accuracy: 0.8865
# Epoch 318/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0484 - accuracy: 0.9797 - val_loss: 0.7883 - val_accuracy: 0.8871
# Epoch 319/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0485 - accuracy: 0.9797 - val_loss: 0.7506 - val_accuracy: 0.8875
# Epoch 320/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0481 - accuracy: 0.9798 - val_loss: 0.7706 - val_accuracy: 0.8869
# Epoch 321/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0481 - accuracy: 0.9798 - val_loss: 0.7567 - val_accuracy: 0.8859
# Epoch 322/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0483 - accuracy: 0.9797 - val_loss: 0.7534 - val_accuracy: 0.8866
# Epoch 323/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0486 - accuracy: 0.9796 - val_loss: 0.7073 - val_accuracy: 0.8856
# Epoch 324/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0487 - accuracy: 0.9796 - val_loss: 0.7575 - val_accuracy: 0.8866
# Epoch 325/4000
# 185/185 [==============================] - 18s 98ms/step - loss: 0.0484 - accuracy: 0.9797 - val_loss: 0.7396 - val_accuracy: 0.8869
# ...
# Epoch 3894/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0223 - accuracy: 0.9907 - val_loss: 1.3712 - val_accuracy: 0.8812
# Epoch 3895/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0223 - accuracy: 0.9907 - val_loss: 1.5641 - val_accuracy: 0.8814
# Epoch 3896/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0224 - accuracy: 0.9907 - val_loss: 1.5332 - val_accuracy: 0.8811
# Epoch 3897/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0225 - accuracy: 0.9906 - val_loss: 1.5179 - val_accuracy: 0.8810
# Epoch 3898/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9906 - val_loss: 1.7150 - val_accuracy: 0.8810
# Epoch 3899/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0226 - accuracy: 0.9906 - val_loss: 1.7779 - val_accuracy: 0.8816
# Epoch 3900/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0225 - accuracy: 0.9906 - val_loss: 1.8313 - val_accuracy: 0.8814
# Epoch 3901/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.8473 - val_accuracy: 0.8809
# Epoch 3902/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.7425 - val_accuracy: 0.8818
# Epoch 3903/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.8343 - val_accuracy: 0.8812
# Epoch 3904/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 1.7041 - val_accuracy: 0.8811
# Epoch 3905/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 1.6441 - val_accuracy: 0.8814
# Epoch 3906/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.6338 - val_accuracy: 0.8813
# Epoch 3907/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.5948 - val_accuracy: 0.8807
# Epoch 3908/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 1.6601 - val_accuracy: 0.8812
# Epoch 3909/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.6124 - val_accuracy: 0.8810
# Epoch 3910/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.6007 - val_accuracy: 0.8807
# Epoch 3911/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0232 - accuracy: 0.9903 - val_loss: 1.5037 - val_accuracy: 0.8807
# Epoch 3912/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.5576 - val_accuracy: 0.8816
# Epoch 3913/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.5292 - val_accuracy: 0.8813
# Epoch 3914/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0232 - accuracy: 0.9903 - val_loss: 1.4542 - val_accuracy: 0.8814
# Epoch 3915/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0231 - accuracy: 0.9903 - val_loss: 1.4576 - val_accuracy: 0.8817
# Epoch 3916/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0226 - accuracy: 0.9906 - val_loss: 1.4972 - val_accuracy: 0.8809
# Epoch 3917/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.4986 - val_accuracy: 0.8814
# Epoch 3918/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.4890 - val_accuracy: 0.8807
# Epoch 3919/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 1.5543 - val_accuracy: 0.8812
# Epoch 3920/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.1510 - accuracy: 0.9460 - val_loss: 0.4196 - val_accuracy: 0.8802
# Epoch 3921/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0933 - accuracy: 0.9637 - val_loss: 0.5907 - val_accuracy: 0.8834
# Epoch 3922/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0582 - accuracy: 0.9759 - val_loss: 0.5073 - val_accuracy: 0.8812
# Epoch 3923/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0517 - accuracy: 0.9786 - val_loss: 0.8298 - val_accuracy: 0.8828
# Epoch 3924/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0381 - accuracy: 0.9842 - val_loss: 0.8987 - val_accuracy: 0.8825
# Epoch 3925/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0333 - accuracy: 0.9862 - val_loss: 0.9648 - val_accuracy: 0.8821
# Epoch 3926/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0298 - accuracy: 0.9876 - val_loss: 1.0109 - val_accuracy: 0.8815
# Epoch 3927/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0272 - accuracy: 0.9886 - val_loss: 1.0658 - val_accuracy: 0.8817
# Epoch 3928/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0254 - accuracy: 0.9894 - val_loss: 1.0873 - val_accuracy: 0.8818
# Epoch 3929/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0245 - accuracy: 0.9898 - val_loss: 1.0960 - val_accuracy: 0.8823
# Epoch 3930/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0238 - accuracy: 0.9900 - val_loss: 1.1593 - val_accuracy: 0.8815
# Epoch 3931/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0232 - accuracy: 0.9903 - val_loss: 1.1490 - val_accuracy: 0.8818
# Epoch 3932/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 1.1572 - val_accuracy: 0.8815
# Epoch 3933/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0225 - accuracy: 0.9906 - val_loss: 1.2449 - val_accuracy: 0.8817
# Epoch 3934/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0226 - accuracy: 0.9906 - val_loss: 1.2509 - val_accuracy: 0.8812
# Epoch 3935/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0223 - accuracy: 0.9907 - val_loss: 1.1887 - val_accuracy: 0.8815
# Epoch 3936/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0222 - accuracy: 0.9907 - val_loss: 1.2919 - val_accuracy: 0.8812
# Epoch 3937/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0222 - accuracy: 0.9907 - val_loss: 1.2933 - val_accuracy: 0.8814
# Epoch 3938/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0224 - accuracy: 0.9906 - val_loss: 1.2608 - val_accuracy: 0.8815
# Epoch 3939/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.3959 - val_accuracy: 0.8809
# Epoch 3940/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.4817 - val_accuracy: 0.8811
# Epoch 3941/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0224 - accuracy: 0.9907 - val_loss: 1.3493 - val_accuracy: 0.8811
# Epoch 3942/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.4216 - val_accuracy: 0.8814
# Epoch 3943/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.3589 - val_accuracy: 0.8814
# Epoch 3944/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.4266 - val_accuracy: 0.8815
# Epoch 3945/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.3764 - val_accuracy: 0.8816
# Epoch 3946/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0226 - accuracy: 0.9906 - val_loss: 1.3721 - val_accuracy: 0.8812
# Epoch 3947/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.2741 - val_accuracy: 0.8813
# Epoch 3948/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0225 - accuracy: 0.9906 - val_loss: 1.4066 - val_accuracy: 0.8815
# Epoch 3949/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.4622 - val_accuracy: 0.8811
# Epoch 3950/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.3871 - val_accuracy: 0.8813
# Epoch 3951/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.3041 - val_accuracy: 0.8812
# Epoch 3952/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0231 - accuracy: 0.9903 - val_loss: 1.2729 - val_accuracy: 0.8815
# Epoch 3953/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0234 - accuracy: 0.9903 - val_loss: 1.3967 - val_accuracy: 0.8817
# Epoch 3954/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 1.4922 - val_accuracy: 0.8814
# Epoch 3955/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.4017 - val_accuracy: 0.8814
# Epoch 3956/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.3575 - val_accuracy: 0.8817
# Epoch 3957/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.2876 - val_accuracy: 0.8811
# Epoch 3958/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.3283 - val_accuracy: 0.8810
# Epoch 3959/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.3980 - val_accuracy: 0.8815
# Epoch 3960/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0239 - accuracy: 0.9900 - val_loss: 1.2845 - val_accuracy: 0.8810
# Epoch 3961/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0232 - accuracy: 0.9903 - val_loss: 1.3533 - val_accuracy: 0.8809
# Epoch 3962/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 1.3084 - val_accuracy: 0.8816
# Epoch 3963/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0231 - accuracy: 0.9904 - val_loss: 1.2873 - val_accuracy: 0.8814
# Epoch 3964/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0232 - accuracy: 0.9903 - val_loss: 1.3403 - val_accuracy: 0.8810
# Epoch 3965/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0235 - accuracy: 0.9902 - val_loss: 1.2441 - val_accuracy: 0.8813
# Epoch 3966/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0232 - accuracy: 0.9903 - val_loss: 1.3318 - val_accuracy: 0.8814
# Epoch 3967/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.3047 - val_accuracy: 0.8814
# Epoch 3968/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.3035 - val_accuracy: 0.8823
# Epoch 3969/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.3644 - val_accuracy: 0.8810
# Epoch 3970/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 1.4294 - val_accuracy: 0.8813
# Epoch 3971/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.3116 - val_accuracy: 0.8810
# Epoch 3972/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.4699 - val_accuracy: 0.8814
# Epoch 3973/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.4768 - val_accuracy: 0.8822
# Epoch 3974/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.5444 - val_accuracy: 0.8814
# Epoch 3975/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.3788 - val_accuracy: 0.8812
# Epoch 3976/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0232 - accuracy: 0.9903 - val_loss: 1.4369 - val_accuracy: 0.8811
# Epoch 3977/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 1.4103 - val_accuracy: 0.8811
# Epoch 3978/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.4193 - val_accuracy: 0.8809
# Epoch 3979/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0225 - accuracy: 0.9906 - val_loss: 1.4194 - val_accuracy: 0.8812
# Epoch 3980/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9904 - val_loss: 1.4595 - val_accuracy: 0.8819
# Epoch 3981/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.2934 - val_accuracy: 0.8818
# Epoch 3982/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0235 - accuracy: 0.9902 - val_loss: 1.4573 - val_accuracy: 0.8810
# Epoch 3983/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0231 - accuracy: 0.9904 - val_loss: 1.4480 - val_accuracy: 0.8810
# Epoch 3984/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0234 - accuracy: 0.9902 - val_loss: 1.4870 - val_accuracy: 0.8809
# Epoch 3985/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0235 - accuracy: 0.9902 - val_loss: 1.5623 - val_accuracy: 0.8806
# Epoch 3986/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.5017 - val_accuracy: 0.8816
# Epoch 3987/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.6227 - val_accuracy: 0.8815
# Epoch 3988/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.5928 - val_accuracy: 0.8812
# Epoch 3989/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.3970 - val_accuracy: 0.8808
# Epoch 3990/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0226 - accuracy: 0.9906 - val_loss: 1.4766 - val_accuracy: 0.8806
# Epoch 3991/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.4413 - val_accuracy: 0.8806
# Epoch 3992/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.3244 - val_accuracy: 0.8814
# Epoch 3993/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0227 - accuracy: 0.9905 - val_loss: 1.6084 - val_accuracy: 0.8814
# Epoch 3994/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0228 - accuracy: 0.9905 - val_loss: 1.4237 - val_accuracy: 0.8810
# Epoch 3995/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0226 - accuracy: 0.9906 - val_loss: 1.5049 - val_accuracy: 0.8817
# Epoch 3996/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0226 - accuracy: 0.9906 - val_loss: 1.3233 - val_accuracy: 0.8811
# Epoch 3997/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0224 - accuracy: 0.9906 - val_loss: 1.4071 - val_accuracy: 0.8813
# Epoch 3998/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0225 - accuracy: 0.9906 - val_loss: 1.4669 - val_accuracy: 0.8815
# Epoch 3999/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0231 - accuracy: 0.9903 - val_loss: 1.5468 - val_accuracy: 0.8808
# Epoch 4000/4000
# 185/185 [==============================] - 18s 99ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 1.5119 - val_accuracy: 0.8813

# %% [markdown]
# <a name='5'></a>
# # 5 - Evaluate Model Results

# %% [markdown]
# <a name='5.1'></a>
# ## 5.1 - Bias Variance Check

# %%
# High Bias is a characteristic of an underfitted model and we would observe low accuracies for both train and validation set
# High Variance is a characterisitic of an overfitted model and we would observe high accuracy for train set and low for validation set
# To check for bias and variance plit the graphs for accuracy 
# I have plotted for loss too, this helps in confirming if the loss is decreasing with each iteration - hence, the model is optimizing fine
fig, axis = plt.subplots(1, 2, figsize=(20, 5))
axis[0].plot(results.history["loss"], color='r', label = 'train loss')
axis[0].plot(results.history["val_loss"], color='b', label = 'dev loss')
axis[0].set_title('Loss Comparison')
axis[0].legend()
axis[1].plot(results.history["accuracy"], color='r', label = 'train accuracy')
axis[1].plot(results.history["val_accuracy"], color='b', label = 'dev accuracy')
axis[1].set_title('Accuracy Comparison')
axis[1].legend()

# RESULTS
# The train loss is consistently decreasing showing that Adam is able to optimize the model and find the minima
# The accuracy of train and validation is ~90% which is high enough, so low bias
# and the %s aren't that far apart, hence low variance

# %% [markdown]
# <a name='5.2'></a>
# ## 5.2 - View Predicted Segmentations

# %%
unet.evaluate(X_valid, y_valid)
# Out:
# 47/47 [==============================] - 2s 32ms/step - loss: 1.5119 - accuracy: 0.8813
# [1.5118558406829834, 0.8813319802284241]

# %%
# Results of Validation Dataset
def VisualizeResults(index):
    img = X_valid[index]
    img = img[np.newaxis, ...]
    pred_y = unet.predict(img)
    pred_mask = tf.argmax(pred_y[0], axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    fig, arr = plt.subplots(1, 3, figsize=(15, 15))
    arr[0].imshow(X_valid[index])
    arr[0].set_title('Processed Image')
    arr[1].imshow(y_valid[index,:,:,0])
    arr[1].set_title('Actual Masked Image ')
    arr[2].imshow(pred_mask[:,:,0])
    arr[2].set_title('Predicted Masked Image ')

# %%
# Add any index to contrast the predicted mask with actual mask
index = 1477
VisualizeResults(index)
# Out:
# 1/1 [==============================] - 1s 577ms/step

# %%
img = X[1]
img = img[np.newaxis, ...]
pred_y = unet.predict(X[1][np.newaxis, ...])
pred_mask = tf.argmax(pred_y[0], axis=-1)
pred_mask = pred_mask[..., tf.newaxis]
fig, arr = plt.subplots(1, 2, figsize=(15, 15))
arr[0].imshow(X[1])
arr[0].set_title('Processed Image')
arr[1].imshow(pred_mask[:,:,0])
arr[1].set_title('Predicted Masked Image ')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Text(0.5, 1.0, 'Predicted Masked Image ')

# %%
m = len('C:/Users/aia200/OneDrive_KNOU/data/custom_sample/KakaoTalk_20221004_195441037.jpg')                     # number of images
i_h,i_w,i_c = target_shape_img   # pull height, width, and channels of image
m_h,m_w,m_c = target_shape_mask  # pull height, width, and channels of mask

# Define X and Y as number of images along with shape of one image
X = np.zeros((128,128, 128, 3), dtype=np.float32)
y = np.zeros((m,m_h,m_w,m_c), dtype=np.int32)

# Resize images and masks
for file in X[4]:
    # convert image into an array of desired shape (3 channels)
    index = X[4].index(file)
    path = os.path.join(path1, file)
    single_img = Image.open(path).convert('RGB')
    single_img = single_img.resize((128, 128))
    single_img = np.reshape(single_img,(128, 128, 3)) 
    single_img = single_img/256.
    X[index] = single_img
    
    # convert mask into an array of desired shape (1 channel)
    single_mask_ind = mask[index]
    path = os.path.join(path2, single_mask_ind)
    single_mask = Image.open(path)
    single_mask = single_mask.resize((m_h, m_w))
    single_mask = np.reshape(single_mask,(m_h,m_w,m_c)) 
    single_mask = single_mask - 1 # to ensure classes #s start from 0
    y[index] = single_mask
return X, y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\aia200\OneDrive_KNOU\1_total_beat\test_202\U_Net_for_Image_Segmentation_From_Scratch_Using_TensorFlow_v4.ipynb 셀 40 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/aia200/OneDrive_KNOU/1_total_beat/test_202/U_Net_for_Image_Segmentation_From_Scratch_Using_TensorFlow_v4.ipynb#X54sZmlsZQ%3D%3D?line=8'>9</a> # Resize images and masks
#      <a href='vscode-notebook-cell:/c%3A/Users/aia200/OneDrive_KNOU/1_total_beat/test_202/U_Net_for_Image_Segmentation_From_Scratch_Using_TensorFlow_v4.ipynb#X54sZmlsZQ%3D%3D?line=9'>10</a> for file in X[4]:
#      <a href='vscode-notebook-cell:/c%3A/Users/aia200/OneDrive_KNOU/1_total_beat/test_202/U_Net_for_Image_Segmentation_From_Scratch_Using_TensorFlow_v4.ipynb#X54sZmlsZQ%3D%3D?line=10'>11</a>     # convert image into an array of desired shape (3 channels)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aia200/OneDrive_KNOU/1_total_beat/test_202/U_Net_for_Image_Segmentation_From_Scratch_Using_TensorFlow_v4.ipynb#X54sZmlsZQ%3D%3D?line=11'>12</a>     index = X[4].index(file)
#      <a href='vscode-notebook-cell:/c%3A/Users/aia200/OneDrive_KNOU/1_total_beat/test_202/U_Net_for_Image_Segmentation_From_Scratch_Using_TensorFlow_v4.ipynb#X54sZmlsZQ%3D%3D?line=12'>13</a>     path = os.path.join(path1, file)
#      <a href='vscode-notebook-cell:/c%3A/Users/aia200/OneDrive_KNOU/1_total_beat/test_202/U_Net_for_Image_Segmentation_From_Scratch_Using_TensorFlow_v4.ipynb#X54sZmlsZQ%3D%3D?line=13'>14</a>     single_img = Image.open(path).convert('RGB')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
len(X[4])
# Out:
# 128

# %%
len('C:/Users/aia200/OneDrive_KNOU/data/custom_sample/IMG_0188.jpg')                     # number of images
# Out:
# 61

# %%
len('C:/Users/aia200/OneDrive_KNOU/data/oxford pets/images/images/Abyssinian_10')
# Out:
# 74

# %%
single_img = Image.open('C:/Users/aia200/OneDrive_KNOU/data/custom_sample/KakaoTalk_20221004_195441037.jpg').convert('RGB')
single_img = single_img.resize((128, 128))
single_img = np.reshape(single_img,(128, 128, 3)) 
single_img = single_img/256.
X[1] = single_img
